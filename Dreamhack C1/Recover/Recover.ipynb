# %%
import os

v6 = [0xDE, 0xAD, 0xBE, 0xEF]
v5 = 0
with open('encrypted', 'rb') as f_in, open('flag_decrypted', 'wb') as f_out:
    content = f_in.read()
    #print(content.hex())

    for i in range(len(content)):
        result = ((content[i]-19)%256)^v6[i%4]
        f_out.write(bytes([result]))
