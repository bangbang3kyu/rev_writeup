# %%
arr = [172, 243, 12, 37, 163, 16, 183, 37, 22, 198, 183, 188,7, 37, 2, 213, 198, 17, 7, 197]
a1 = []
for i in range(len(arr)):
    a1.append(chr((arr[i]*51)&255))

print("".join(a1))
# Out:
# Did_y0u_brute_force?

# %%
print((68 * -5) & 255)
print((172*51) & 255)
# Out:
# 172
# 68
