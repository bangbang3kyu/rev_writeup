# %%
arr = [73, 96, 103, 116, 99, 103, 66, 102, 128, 120, 105, 105, 123, 153, 109, 136, 104, 148, 159, 141, 77, 165, 157, 69]
a = []

# 0부터 23까지 반복
for i in range(0, 24):
    a.append(((arr[i] - 2 * i) ) ^ i)

print(a)

a1_result = []

for i in a:
    a1_result.append(chr(i))

print("".join(a1_result))
# Out:
# [73, 95, 97, 109, 95, 88, 48, 95, 120, 111, 95, 88, 111, 114, 95, 101, 88, 99, 105, 116, 49, 110, 103, 0]
# I_am_X0_xo_Xor_eXcit1ng
