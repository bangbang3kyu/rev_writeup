# %%
arr = [
    99, 124, 119, 123, 242, 107, 111, 197, 48, 1, 103, 43,
    254, 215, 171, 118, 202, 130, 201, 125, 250, 89, 71,
    240, 173, 212, 162, 175, 156, 164, 114, 192, 183, 253,
    147, 38, 54, 63, 247, 204, 52, 165, 229, 241, 113, 216,
    49, 21, 4, 199, 35, 195, 24, 150, 5, 154, 7, 18, 128,
    226, 235, 39, 178, 117, 9, 131, 44, 26, 27, 110, 90,
    160, 82, 59, 214, 179, 41, 227, 47, 132, 83, 209, 0,
    237, 32, 252, 177, 91, 106, 203, 190, 57, 74, 76, 88,
    207, 208, 239, 170, 251, 67, 77, 51, 133, 69, 249, 2,
    127, 80, 60, 159, 168, 81, 163, 64, 143, 146, 157, 56,
    245, 188, 182, 218, 33, 16, 255, 243, 210, 205, 12,
    19, 236, 95, 151, 68, 23, 196, 167, 126, 61, 100, 93,
    25, 115, 96, 129, 79, 220, 34, 42, 144, 136, 70, 238,
    184, 20, 222, 94, 11, 219, 224, 50, 58, 10, 73, 6, 36,
    92, 194, 211, 172, 98, 145, 149, 228, 121, 231, 200,
    55, 109, 141, 213, 78, 169, 108, 86, 244, 234, 101,
    122, 174, 8, 186, 120, 37, 46, 28, 166, 180, 198, 232,
    221, 116, 31, 75, 189, 139, 138, 112, 62, 181, 102,
    72, 3, 246, 14, 97, 53, 87, 185, 134, 193, 29, 158,
    225, 248, 152, 17, 105, 217, 142, 148, 155, 30, 135,
    233, 206, 85, 40, 223, 140, 161, 137, 13, 191, 230,
    66, 104, 65, 153, 45, 15, 176, 84, 187, 22
]

unk_140004000 = [
    0x7E, 0x7D, 0x9A, 0x8B, 0x25, 0x2D, 0xD5, 0x3D,
    0x03, 0x2B, 0x38, 0x98, 0x27, 0x9F, 0x4F, 0xBC,
    0x2A, 0x79, 0x00, 0x7D, 0xC4, 0x2A, 0x4F, 0x58,
    0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
]

# %%
for i in range(0,25,8):
    print(i)
# Out:
# 0
# 8
# 16
# 24

# %%
0&7
# Out:
# 0

# %%
def rol1(val, count):
    val &= 0xff
    return ((val << count) | (val >> (8 - count))) & 0xff

v5 = "I_am_KEY"

block = unk_140004000[24:32]

print(block)

for i in range(15, -1, -1):
    for j in range(7, -1, -1):
        idx = (j + 1) & 7
        v2 = block[j]

        value = rol1(block[idx], 5) - arr[ord(v5[j]) ^ v2]
        value &= 0xff

        block[idx] = value

print(block)

result = []

for i in block:
    print(chr(i))
# Out:
# [0, 0, 0, 0, 0, 0, 0, 0]
# [148, 112, 203, 84, 62, 165, 72, 100]
# 
# p
# Ë
# T
# >
# ¥
# H
# d

# %%
for z in range(0, 17, 8):
    print(z)
# Out:
# 0
# 8
# 16

# %%
def rol1(val, count):
    val &= 0xff
    return ((val << count) | (val >> (8 - count))) & 0xff

v5 = "I_am_KEY"

result = []

for z in range(0, 17, 8):
    block = unk_140004000[z:z+8]
    for i in range(15, -1, -1):
        for j in range(7, -1, -1):
            idx = (j + 1) & 7
            v2 = block[j]

            value = rol1(block[idx], 5) - arr[ord(v5[j]) ^ v2]
            value &= 0xff

            block[idx] = value

    #print(block)
    for i in block:
        result.append(chr(i))

print("".join(result))
# Out:
# Reverse__your__brain_;)

# %%
def rol1(val, count):
    val &= 0xff
    return ((val << count) | (val >> (8 - count))) & 0xff

v5 = "I_am_KEY"

block = unk_140004000[8:16]

for i in range(15, -1, -1):
    for j in range(7, -1, -1):
        idx = (j + 1) & 7
        v2 = block[j & 7]

        value = rol1(block[idx], 5) - arr[ord(v5[j]) ^ v2]
        value &= 0xff

        block[idx] = value

print(block)

result2 = []

for i in block:
    result2.append(chr(i))

print("".join(result2))
# Out:
# [95, 121, 111, 117, 114, 95, 95, 98]
# _your__b

# %%
def rol1(val, count):
    val &= 0xff
    return ((val << count) | (val >> (8 - count))) & 0xff

v5 = "I_am_KEY"

block = unk_140004000[0:8]

for i in range(15, -1, -1):
    for j in range(7, -1, -1):
        idx = (j + 1) & 7
        v2 = block[j & 7]

        value = rol1(block[idx], 5) - arr[ord(v5[j]) ^ v2]
        value &= 0xff

        block[idx] = value

print(block)

result1 = []

for i in block:
    result1.append(chr(i))

print("".join(result1))
# Out:
# [82, 101, 118, 101, 114, 115, 101, 95]
# Reverse_

# %%
print("".join(result1+result2+result3))
# Out:
# Reverse__your__brain_;)

# %%
a = "flag"
b = "ffff"

print(b[1]==a)
