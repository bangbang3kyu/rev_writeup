# %%
import hashlib
a = pow(3, 312647161260980926, 2**63) # 2031358425278567737
print(a)
b = pow(16045690984833335023,2031358425278567737,2**64) # 4913979886115108719
print(b)

binary_data = b.to_bytes(8, byteorder='little')
sha256_hash = hashlib.sha256(binary_data)
print(sha256_hash)
print(sha256_hash.hexdigest())
# Out:
# 2031358425278567737
# 4913979886115108719
# <sha256 _hashlib.HASH object @ 0x0000016055ADFC30>
# 22f77ed522bc94e705ab54a6e198ba706d447bfd08459985829631f1389e9c27

# %%
import hashlib
a = pow(3, 312647161260980926, 2**63) # 2031358425278567737
# print(a)
b = pow(16045690984833335023,2031358425278567737,2**64) # 4913979886115108719
# print(b)

binary_data = b.to_bytes(8, byteorder='little')
sha256_hash = hashlib.sha256(binary_data)
# print(sha256_hash)
print(sha256_hash.hexdigest())
# 22f77ed522bc94e705ab54a6e198ba706d447bfd08459985829631f1389e9c27

a0123456789abcd =  '0123456789abcdef'
#print(a0123456789abcd[0])
v3 = [0] * 64
a1 = '22f77ed522bc94e705ab54a6e198ba706d447bfd08459985829631f1389e9c27'

hex_a1=bytes.fromhex(a1)

for i in range(0,32):
    index = hex_a1[i]
    v3[2*i]=a0123456789abcd[index >> 4]
    v3[2*i+1]=a0123456789abcd[index&15]

print("".join(v3))
# Out:
# 22f77ed522bc94e705ab54a6e198ba706d447bfd08459985829631f1389e9c27
# 22f77ed522bc94e705ab54a6e198ba706d447bfd08459985829631f1389e9c27
