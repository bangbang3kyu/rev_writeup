# %%
import numpy as np
target = "C@qpl==Bppl@<=pG<>@l>@Blsp<@l@AArqmGr=B@A>q@@B=GEsmC@ArBmAGlA=@q"

result = []

for c in target:
    result.append(ord(c)^3)

print(result)
rot = list(reversed(result))
print(rot)

input = []

for i in rot:
    input.append(((i-13)&127)%256)

print(input)

answer = []

for r in input:
    answer.append(chr(r))

print("".join(answer))
# Out:
# [64, 67, 114, 115, 111, 62, 62, 65, 115, 115, 111, 67, 63, 62, 115, 68, 63, 61, 67, 111, 61, 67, 65, 111, 112, 115, 63, 67, 111, 67, 66, 66, 113, 114, 110, 68, 113, 62, 65, 67, 66, 61, 114, 67, 67, 65, 62, 68, 70, 112, 110, 64, 67, 66, 113, 65, 110, 66, 68, 111, 66, 62, 67, 114]
# [114, 67, 62, 66, 111, 68, 66, 110, 65, 113, 66, 67, 64, 110, 112, 70, 68, 62, 65, 67, 67, 114, 61, 66, 67, 65, 62, 113, 68, 110, 114, 113, 66, 66, 67, 111, 67, 63, 115, 112, 111, 65, 67, 61, 111, 67, 61, 63, 68, 115, 62, 63, 67, 111, 115, 115, 65, 62, 62, 111, 115, 114, 67, 64]
# [101, 54, 49, 53, 98, 55, 53, 97, 52, 100, 53, 54, 51, 97, 99, 57, 55, 49, 52, 54, 54, 101, 48, 53, 54, 52, 49, 100, 55, 97, 101, 100, 53, 53, 54, 98, 54, 50, 102, 99, 98, 52, 54, 48, 98, 54, 48, 50, 55, 102, 49, 50, 54, 98, 102, 102, 52, 49, 49, 98, 102, 101, 54, 51]
# e615b75a4d563ac971466e05641d7aed556b62fcb460b6027f126bff411bfe63
