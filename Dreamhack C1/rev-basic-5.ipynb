# %%
import string
arr = [173, 216, 203,203, 157, 151, 203, 196, 146, 161,210, 215, 210, 214, 168, 165, 220, 199, 173, 163, 161,152, 76]

my_characters = string.ascii_letters + string.punctuation
a1 = []

for i in range(len(my_characters)):
    a1 = [ord(my_characters[i])]
    for j in range(1,24):
        a1.append(((arr[j-1]-a1[j-1])&0xFF))  
        
    print(a1)
# Out:
# [97, 76, 140, 63, 140, 17, 134, 69, 127, 19, 142, 68, 147, 63, 151, 17, 148, 72, 127, 46, 117, 44, 108, 224]
# [98, 75, 141, 62, 141, 16, 135, 68, 128, 18, 143, 67, 148, 62, 152, 16, 149, 71, 128, 45, 118, 43, 109, 223]
# [99, 74, 142, 61, 142, 15, 136, 67, 129, 17, 144, 66, 149, 61, 153, 15, 150, 70, 129, 44, 119, 42, 110, 222]
# [100, 73, 143, 60, 143, 14, 137, 66, 130, 16, 145, 65, 150, 60, 154, 14, 151, 69, 130, 43, 120, 41, 111, 221]
# [101, 72, 144, 59, 144, 13, 138, 65, 131, 15, 146, 64, 151, 59, 155, 13, 152, 68, 131, 42, 121, 40, 112, 220]
# [102, 71, 145, 58, 145, 12, 139, 64, 132, 14, 147, 63, 152, 58, 156, 12, 153, 67, 132, 41, 122, 39, 113, 219]
# [103, 70, 146, 57, 146, 11, 140, 63, 133, 13, 148, 62, 153, 57, 157, 11, 154, 66, 133, 40, 123, 38, 114, 218]
# [104, 69, 147, 56, 147, 10, 141, 62, 134, 12, 149, 61, 154, 56, 158, 10, 155, 65, 134, 39, 124, 37, 115, 217]
# ...
